# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'Nnz3oz6Bd8GpsM4kS_1e'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
r = requests.get('https://www.quandl.com/api/v3/datasets/XFRA/ADS.json?start_date=2017-01-01&end_date=2017-12-31&api_key=Nnz3oz6Bd8GpsM4kS_1e')

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
r.json()
# Out:
# {'dataset': {'id': 46112467,
#   'dataset_code': 'ADS',
#   'database_code': 'XFRA',
#   'name': 'Adidas AG (ADS) Adjusted Stock Prices',
#   'description': ' <b>Ticker</b>: ADS <br> <br> <b>Exchange</b>: XFRA <br> <br> Columns: <br> <br> Open,High,Low,Close,Volume are adjusted and shown in EUR currency. <br> <br> Adjustment Factor shows the factor by which prices are adjusted on days which adjustments take place <br> <br> Adjustment Type is a number representing the type of adjustment. Refer to documentation for more information on these codes.',
#   'refreshed_at': '2021-05-11T04:55:29.052Z',
#   'newest_available_date': '2018-11-30',
#   'oldest_available_date': '2007-01-02',
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Volume',
#    'Adjustment Factor',
#    'Adjustment Type'],
#   'frequency': 'daily',
#   'type': 'Time Series',
#   'premium': True,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '2017-01-01',
#   'end_date': '2017-12-31',
#   'data': [['2017-12-29',
#     164.251989,
#     164.251989,
#     162.848566,
#     162.872897,
#     1060.0,
#     None,
#     None],
#    ['2017-12-28',
#     165.350784,
#     165.350784,
#     163.683612,
#     163.956121,
#     1019.0,
#     None,
#     None],
#    ['2017-12-27',
#     166.006753,
#     166.006753,
#     164.829124,
#     165.348838,
#     1121.0,
#     None,
#     None],
#    ['2017-12-26',
#     164.965379,
#     164.965379,
#     164.965379,
#     164.965379,
#     0.0,
#     None,
#     None],
#    ['2017-12-25',
#     164.965379,
#     164.965379,
#     164.965379,
#     164.965379,
#     0.0,
#     None,
#     None],
#    ['2017-12-22',
#     165.20869,
#     165.670983,
#     164.478755,
#     164.965379,
#     2067.0,
#     None,
#     None],
#    ['2017-12-21',
#     165.843247,
#     166.59946,
#     164.478755,
#     165.302122,
#     2173.0,
#     None,
#     None],
#    ['2017-12-20',
#     168.297777,
#     168.297777,
#     165.452002,
#     165.832542,
#     1489.0,
#     None,
#     None],
#    ['2017-12-19',
#     168.93136,
#     169.34499,
#     168.288044,
#     168.33768,
#     752.0,
#     None,
#     None],
#    ['2017-12-18',
#     169.393653,
#     169.61458,
#     168.201425,
#     168.93136,
#     1661.0,
#     None,
#     None],
#    ['2017-12-15',
#     163.641763,
#     167.759571,
#     163.603806,
#     167.759571,
#     1826.0,
#     None,
#     None],
#    ['2017-12-14',
#     164.057339,
#     166.279262,
#     161.364364,
#     163.700157,
#     3261.0,
#     None,
#     None],
#    ['2017-12-13',
#     169.801443,
#     169.801443,
#     162.777519,
#     163.807215,
#     5067.0,
#     None,
#     None],
#    ['2017-12-12',
#     171.441365,
#     171.596111,
#     168.371743,
#     169.34499,
#     2348.0,
#     None,
#     None],
#    ['2017-12-11',
#     176.653103,
#     176.653103,
#     169.588302,
#     171.039414,
#     2903.0,
#     None,
#     None],
#    ['2017-12-08',
#     176.573296,
#     176.884736,
#     175.74409,
#     176.284242,
#     2083.0,
#     None,
#     None],
#    ['2017-12-07',
#     175.285691,
#     175.864773,
#     174.454538,
#     175.864773,
#     1281.0,
#     None,
#     None],
#    ['2017-12-06',
#     171.720687,
#     174.941161,
#     171.290511,
#     174.499307,
#     1351.0,
#     None,
#     None],
#    ['2017-12-05',
#     172.311448,
#     173.078366,
#     171.048173,
#     172.645271,
#     1917.0,
#     None,
#     None],
#    ['2017-12-04',
#     172.313394,
#     172.65695,
#     171.819958,
#     172.452568,
#     1975.0,
#     None,
#     None],
#    ['2017-12-01',
#     171.371291,
#     171.914363,
#     170.318238,
#     171.076397,
#     3104.0,
#     None,
#     None],
#    ['2017-11-30',
#     172.544054,
#     173.056955,
#     170.458385,
#     170.884667,
#     1521.0,
#     None,
#     None],
#    ['2017-11-29',
#     174.472056,
#     176.594708,
#     172.374709,
#     172.852573,
#     1363.0,
#     None,
#     None],
#    ['2017-11-28',
#     174.288112,
#     175.184473,
#     174.162563,
#     174.360133,
#     880.0,
#     None,
#     None],
#    ['2017-11-27',
#     175.217563,
#     175.841415,
#     174.073025,
#     174.263781,
#     2280.0,
#     None,
#     None],
#    ['2017-11-24',
#     176.690086,
#     177.464791,
#     175.184473,
#     176.073047,
#     2592.0,
#     None,
#     None],
#    ['2017-11-23',
#     177.823919,
#     177.823919,
#     176.803956,
#     176.821474,
#     814.0,
#     None,
#     None],
#    ['2017-11-22',
#     182.035159,
#     182.73979,
#     177.81224,
#     178.590838,
#     2712.0,
#     None,
#     None],
#    ['2017-11-21',
#     180.050708,
#     182.532488,
#     179.682821,
#     182.531515,
#     2106.0,
#     None,
#     None],
#    ['2017-11-20',
#     178.778674,
#     181.461916,
#     178.778674,
#     180.262876,
#     2654.0,
#     None,
#     None],
#    ['2017-11-17',
#     179.905694,
#     181.315929,
#     179.904721,
#     180.659961,
#     779.0,
#     None,
#     None],
#    ['2017-11-16',
#     181.246829,
#     182.301829,
#     179.382087,
#     179.905694,
#     636.0,
#     None,
#     None],
#    ['2017-11-15',
#     182.375795,
#     182.375795,
#     178.452637,
#     181.191354,
#     2694.0,
#     None,
#     None],
#    ['2017-11-14',
#     179.435616,
#     183.220574,
#     178.306649,
#     182.408886,
#     2052.0,
#     None,
#     None],
#    ['2017-11-13',
#     177.827812,
#     179.480385,
#     176.002,
#     179.077461,
#     1926.0,
#     None,
#     None],
#    ['2017-11-10',
#     171.972758,
#     176.991793,
#     171.291485,
#     176.348476,
#     6443.0,
#     None,
#     None],
#    ['2017-11-09',
#     181.340261,
#     181.350966,
#     170.269575,
#     171.290511,
#     13020.0,
#     None,
#     None],
#    ['2017-11-08',
#     178.927581,
#     180.33003,
#     178.927581,
#     179.765547,
#     503.0,
#     None,
#     None],
#    ['2017-11-07',
#     178.848748,
#     179.418098,
#     178.250201,
#     178.511031,
#     1410.0,
#     None,
#     None],
#    ['2017-11-06',
#     182.288203,
#     182.288203,
#     177.836571,
#     177.866742,
#     4602.0,
#     None,
#     None],
#    ['2017-11-03',
#     182.524702,
#     183.255611,
#     181.697442,
#     182.364117,
#     849.0,
#     None,
#     None],
#    ['2017-11-02',
#     182.807917,
#     184.66098,
#     181.793794,
#     182.174333,
#     737.0,
#     None,
#     None],
#    ['2017-11-01',
#     187.17293,
#     187.17293,
#     182.218129,
#     182.673609,
#     2762.0,
#     None,
#     None],
#    ['2017-10-31',
#     186.025472,
#     186.025472,
#     186.025472,
#     186.025472,
#     0.0,
#     None,
#     None],
#    ['2017-10-30',
#     185.841528,
#     186.710638,
#     185.496999,
#     186.025472,
#     1656.0,
#     None,
#     None],
#    ['2017-10-27',
#     185.330574,
#     187.329623,
#     185.330574,
#     185.890191,
#     781.0,
#     None,
#     None],
#    ['2017-10-26',
#     181.809366,
#     185.471694,
#     181.809366,
#     185.403567,
#     663.0,
#     None,
#     None],
#    ['2017-10-25',
#     182.674582,
#     183.406464,
#     181.016169,
#     181.94854,
#     1593.0,
#     None,
#     None],
#    ['2017-10-24',
#     182.05657,
#     183.177751,
#     181.458023,
#     182.386501,
#     1011.0,
#     None,
#     None],
#    ['2017-10-23',
#     182.970449,
#     184.053673,
#     181.649753,
#     182.537354,
#     835.0,
#     None,
#     None],
#    ['2017-10-20',
#     182.603535,
#     183.00646,
#     181.980657,
#     182.156815,
#     539.0,
#     None,
#     None],
#    ['2017-10-19',
#     186.082894,
#     186.082894,
#     181.731506,
#     181.758757,
#     1841.0,
#     None,
#     None],
#    ['2017-10-18',
#     186.682414,
#     186.764167,
#     184.102336,
#     184.102336,
#     820.0,
#     None,
#     None],
#    ['2017-10-17',
#     186.861491,
#     188.067344,
#     185.841528,
#     185.841528,
#     211.0,
#     None,
#     None],
#    ['2017-10-16',
#     188.487787,
#     188.487787,
#     186.510149,
#     187.053221,
#     1411.0,
#     None,
#     None],
#    ['2017-10-13',
#     188.648373,
#     189.304341,
#     188.022575,
#     188.022575,
#     970.0,
#     None,
#     None],
#    ['2017-10-12',
#     188.809932,
#     189.289743,
#     188.330121,
#     188.921855,
#     165.0,
#     None,
#     None],
#    ['2017-10-11',
#     189.734517,
#     190.210434,
#     188.407981,
#     188.669784,
#     239.0,
#     None,
#     None],
#    ['2017-10-10',
#     190.013839,
#     190.938423,
#     189.260545,
#     189.728677,
#     492.0,
#     None,
#     None],
#    ['2017-10-09',
#     188.010896,
#     189.925273,
#     187.836685,
#     189.644978,
#     696.0,
#     None,
#     None],
#    ['2017-10-06',
#     189.537921,
#     189.537921,
#     187.210887,
#     187.210887,
#     1423.0,
#     None,
#     None],
#    ['2017-10-05',
#     190.10727,
#     191.316043,
#     188.725259,
#     188.725259,
#     1123.0,
#     None,
#     None],
#    ['2017-10-04',
#     191.727727,
#     191.727727,
#     189.108719,
#     189.527215,
#     1493.0,
#     None,
#     None],
#    ['2017-10-03',
#     190.708737,
#     190.708737,
#     190.708737,
#     190.708737,
#     0.0,
#     None,
#     None],
#    ['2017-10-02',
#     187.311131,
#     191.576873,
#     187.311131,
#     190.708737,
#     5681.0,
#     None,
#     None],
#    ['2017-09-29',
#     183.845399,
#     186.610393,
#     183.845399,
#     186.30966,
#     595.0,
#     None,
#     None],
#    ['2017-09-28',
#     183.733475,
#     183.733475,
#     182.662903,
#     183.534933,
#     1046.0,
#     None,
#     None],
#    ['2017-09-27',
#     181.806446,
#     185.050278,
#     181.248775,
#     183.190403,
#     4222.0,
#     None,
#     None],
#    ['2017-09-26',
#     186.792391,
#     186.792391,
#     182.483826,
#     182.659984,
#     1402.0,
#     None,
#     None],
#    ['2017-09-25',
#     186.38752,
#     188.894604,
#     186.38752,
#     187.370499,
#     945.0,
#     None,
#     None],
#    ['2017-09-22',
#     187.632303,
#     188.121846,
#     186.864411,
#     186.864411,
#     1605.0,
#     None,
#     None],
#    ['2017-09-21',
#     189.737436,
#     189.737436,
#     186.996773,
#     188.48876,
#     585.0,
#     None,
#     None],
#    ['2017-09-20',
#     190.048875,
#     190.048875,
#     187.836685,
#     188.118926,
#     1959.0,
#     None,
#     None],
#    ['2017-09-19',
#     192.111186,
#     192.111186,
#     189.563225,
#     189.563225,
#     274.0,
#     None,
#     None],
#    ['2017-09-18',
#     192.871292,
#     193.676167,
#     191.450351,
#     191.613857,
#     255.0,
#     None,
#     None],
#    ['2017-09-15',
#     192.693188,
#     193.225554,
#     192.693188,
#     192.717519,
#     200.0,
#     None,
#     None],
#    ['2017-09-14',
#     193.675194,
#     193.675194,
#     191.729673,
#     192.495619,
#     921.0,
#     None,
#     None],
#    ['2017-09-13',
#     192.122865,
#     193.748188,
#     192.122865,
#     193.748188,
#     460.0,
#     None,
#     None],
#    ['2017-09-12',
#     192.019701,
#     192.787593,
#     192.019701,
#     192.709733,
#     156.0,
#     None,
#     None],
#    ['2017-09-11',
#     191.218718,
#     192.823603,
#     191.218718,
#     192.823603,
#     1769.0,
#     None,
#     None],
#    ['2017-09-08',
#     189.590476,
#     190.075153,
#     188.587058,
#     189.669309,
#     532.0,
#     None,
#     None],
#    ['2017-09-07',
#     186.369028,
#     190.756426,
#     186.369028,
#     190.031357,
#     797.0,
#     None,
#     None],
#    ['2017-09-06',
#     183.38116,
#     186.956869,
#     182.519836,
#     186.956869,
#     861.0,
#     None,
#     None],
#    ['2017-09-05',
#     184.535431,
#     184.535431,
#     184.535431,
#     184.535431,
#     0.0,
#     None,
#     None],
#    ['2017-09-04',
#     183.816201,
#     185.147603,
#     183.687733,
#     184.535431,
#     528.0,
#     None,
#     None],
#    ['2017-09-01',
#     183.985546,
#     186.802123,
#     183.985546,
#     185.29067,
#     669.0,
#     None,
#     None],
#    ['2017-08-31',
#     181.967032,
#     184.034208,
#     181.568,
#     183.707197,
#     946.0,
#     None,
#     None],
#    ['2017-08-30',
#     178.394242,
#     182.177253,
#     178.394242,
#     181.123227,
#     564.0,
#     None,
#     None],
#    ['2017-08-29',
#     178.983056,
#     178.983056,
#     176.900307,
#     177.914431,
#     1422.0,
#     None,
#     None],
#    ['2017-08-28',
#     182.086741,
#     182.086741,
#     180.349495,
#     180.561663,
#     1660.0,
#     None,
#     None],
#    ['2017-08-25',
#     181.014223,
#     183.790897,
#     180.306672,
#     182.873125,
#     2191.0,
#     None,
#     None],
#    ['2017-08-24',
#     183.255611,
#     185.157336,
#     182.62008,
#     182.62008,
#     6148.0,
#     None,
#     None],
#    ['2017-08-23',
#     184.357327,
#     184.357327,
#     184.357327,
#     184.357327,
#     0.0,
#     None,
#     None],
#    ['2017-08-22',
#     183.700385,
#     184.664873,
#     183.700385,
#     184.357327,
#     333.0,
#     None,
#     None],
#    ['2017-08-21',
#     184.438106,
#     184.912077,
#     181.863868,
#     182.485772,
#     562.0,
#     None,
#     None],
#    ['2017-08-18',
#     186.425477,
#     186.425477,
#     178.703734,
#     184.128613,
#     3420.0,
#     None,
#     None],
#    ['2017-08-17',
#     188.466376,
#     188.466376,
#     186.060509,
#     186.339831,
#     316.0,
#     None,
#     None],
#    ['2017-08-16',
#     189.214803,
#     190.275642,
#     188.238636,
#     188.277566,
#     2014.0,
#     None,
#     None],
#    ['2017-08-15',
#     188.889738,
#     190.25715,
#     188.889738,
#     189.266385,
#     470.0,
#     None,
#     None],
#    ['2017-08-14',
#     187.876588,
#     189.004581,
#     186.730103,
#     187.77537,
#     1556.0,
#     None,
#     None],
#    ['2017-08-11',
#     184.393337,
#     186.899448,
#     184.393337,
#     186.788498,
#     1745.0,
#     None,
#     None],
#    ['2017-08-10',
#     188.225984,
#     188.225984,
#     184.988964,
#     184.988964,
#     1675.0,
#     None,
#     None],
#    ['2017-08-09',
#     193.217768,
#     193.217768,
#     188.264914,
#     188.274646,
#     1425.0,
#     None,
#     None],
#    ['2017-08-08',
#     193.968141,
#     194.442113,
#     192.654258,
#     193.681033,
#     1210.0,
#     None,
#     None],
#    ['2017-08-07',
#     193.121416,
#     194.162791,
#     192.604622,
#     193.929211,
#     1360.0,
#     None,
#     None],
#    ['2017-08-04',
#     187.528165,
#     195.635314,
#     187.528165,
#     194.078118,
#     2618.0,
#     None,
#     None],
#    ['2017-08-03',
#     187.445439,
#     188.030361,
#     183.936884,
#     188.029388,
#     2454.0,
#     None,
#     None],
#    ['2017-08-02',
#     186.50431,
#     188.517958,
#     186.50431,
#     186.737889,
#     706.0,
#     None,
#     None],
#    ['2017-08-01',
#     187.704323,
#     188.288271,
#     186.230827,
#     186.766113,
#     1238.0,
#     None,
#     None],
#    ['2017-07-31',
#     187.774397,
#     188.371971,
#     186.863438,
#     187.566122,
#     1751.0,
#     None,
#     None],
#    ['2017-07-28',
#     180.512027,
#     188.323308,
#     179.928079,
#     187.716002,
#     10388.0,
#     None,
#     None],
#    ['2017-07-27',
#     171.970811,
#     179.953384,
#     171.970811,
#     178.60057,
#     4820.0,
#     None,
#     None],
#    ['2017-07-26',
#     171.586378,
#     172.738703,
#     171.586378,
#     172.294902,
#     124.0,
#     None,
#     None],
#    ['2017-07-25',
#     171.953293,
#     172.641378,
#     171.19416,
#     172.011687,
#     885.0,
#     None,
#     None],
#    ['2017-07-24',
#     172.160594,
#     173.238952,
#     171.911443,
#     172.265705,
#     667.0,
#     None,
#     None],
#    ['2017-07-21',
#     175.131918,
#     175.463795,
#     172.306581,
#     172.306581,
#     179.0,
#     None,
#     None],
#    ['2017-07-20',
#     174.574247,
#     176.242392,
#     173.744067,
#     174.775709,
#     284.0,
#     None,
#     None],
#    ['2017-07-19',
#     175.319754,
#     175.466715,
#     174.229717,
#     174.448698,
#     524.0,
#     None,
#     None],
#    ['2017-07-18',
#     177.226345,
#     177.226345,
#     174.587872,
#     175.238975,
#     878.0,
#     None,
#     None],
#    ['2017-07-17',
#     176.644343,
#     178.104214,
#     175.269145,
#     177.380118,
#     1612.0,
#     None,
#     None],
#    ['2017-07-14',
#     175.47742,
#     176.00492,
#     175.197125,
#     175.667203,
#     1670.0,
#     None,
#     None],
#    ['2017-07-13',
#     173.999058,
#     175.742143,
#     173.537739,
#     175.674016,
#     503.0,
#     None,
#     None],
#    ['2017-07-12',
#     170.088551,
#     174.211226,
#     170.088551,
#     173.621438,
#     3761.0,
#     None,
#     None],
#    ['2017-07-11',
#     170.55279,
#     171.23017,
#     169.831614,
#     170.3669,
#     893.0,
#     None,
#     None],
#    ['2017-07-10',
#     172.35427,
#     172.35427,
#     170.243297,
#     170.617998,
#     472.0,
#     None,
#     None],
#    ['2017-07-07',
#     171.088076,
#     171.716794,
#     170.451572,
#     171.450124,
#     659.0,
#     None,
#     None],
#    ['2017-07-06',
#     172.607315,
#     173.630197,
#     170.259843,
#     171.788814,
#     3333.0,
#     None,
#     None],
#    ['2017-07-05',
#     166.186804,
#     172.744542,
#     166.186804,
#     172.130424,
#     2892.0,
#     None,
#     None],
#    ['2017-07-04',
#     163.992132,
#     164.324009,
#     163.687505,
#     164.033981,
#     655.0,
#     None,
#     None],
#    ['2017-07-03',
#     164.555642,
#     165.118178,
#     163.74882,
#     164.361965,
#     682.0,
#     None,
#     None],
#    ['2017-06-30',
#     160.147806,
#     165.041292,
#     160.147806,
#     164.215978,
#     2058.0,
#     None,
#     None],
#    ['2017-06-29',
#     164.377537,
#     164.377537,
#     159.271883,
#     160.165324,
#     2741.0,
#     None,
#     None],
#    ['2017-06-28',
#     164.047607,
#     164.047607,
#     164.047607,
#     164.047607,
#     0.0,
#     None,
#     None],
#    ['2017-06-27',
#     164.09043,
#     164.402842,
#     163.103557,
#     164.047607,
#     617.0,
#     None,
#     None],
#    ['2017-06-26',
#     164.518658,
#     165.231075,
#     163.992132,
#     164.46513,
#     1105.0,
#     None,
#     None],
#    ['2017-06-23',
#     165.1756,
#     165.1756,
#     163.658308,
#     164.368778,
#     434.0,
#     None,
#     None],
#    ['2017-06-22',
#     166.451527,
#     166.451527,
#     165.088981,
#     165.088981,
#     517.0,
#     None,
#     None],
#    ['2017-06-21',
#     167.420881,
#     167.420881,
#     165.20869,
#     166.347389,
#     368.0,
#     None,
#     None],
#    ['2017-06-20',
#     170.428214,
#     170.428214,
#     167.422827,
#     167.422827,
#     270.0,
#     None,
#     None],
#    ['2017-06-19',
#     169.91434,
#     170.548897,
#     169.50363,
#     170.229672,
#     342.0,
#     None,
#     None],
#    ['2017-06-16',
#     169.12017,
#     170.013611,
#     168.704594,
#     169.399492,
#     448.0,
#     None,
#     None],
#    ['2017-06-15',
#     172.730917,
#     172.730917,
#     168.828196,
#     168.828196,
#     100.0,
#     None,
#     None],
#    ['2017-06-14',
#     170.853523,
#     173.773265,
#     170.026263,
#     172.927513,
#     2326.0,
#     None,
#     None],
#    ['2017-06-13',
#     167.635969,
#     171.327495,
#     167.398496,
#     171.048173,
#     1257.0,
#     None,
#     None],
#    ['2017-06-12',
#     164.965379,
#     168.060304,
#     164.579973,
#     167.88512,
#     564.0,
#     None,
#     None],
#    ['2017-06-09',
#     164.216952,
#     165.527915,
#     163.863663,
#     165.527915,
#     545.0,
#     None,
#     None],
#    ['2017-06-08',
#     167.107495,
#     167.107495,
#     164.014516,
#     164.361965,
#     552.0,
#     None,
#     None],
#    ['2017-06-07',
#     163.893834,
#     166.534253,
#     162.973142,
#     166.472938,
#     1526.0,
#     None,
#     None],
#    ['2017-06-06',
#     166.473912,
#     166.814548,
#     164.478755,
#     164.756131,
#     1689.0,
#     None,
#     None],
#    ['2017-06-05',
#     167.064673,
#     167.064673,
#     167.064673,
#     167.064673,
#     0.0,
#     None,
#     None],
#    ['2017-06-02',
#     166.955669,
#     168.364931,
#     166.885595,
#     167.064673,
#     1847.0,
#     None,
#     None],
#    ['2017-06-01',
#     166.30554,
#     167.044234,
#     166.296781,
#     166.619899,
#     291.0,
#     None,
#     None],
#    ['2017-05-31',
#     169.277836,
#     169.407278,
#     165.738137,
#     166.166366,
#     539.0,
#     None,
#     None],
#    ['2017-05-30',
#     167.857869,
#     169.635018,
#     167.31869,
#     169.526988,
#     1065.0,
#     None,
#     None],
#    ['2017-05-29',
#     167.836457,
#     168.37369,
#     167.58536,
#     168.372717,
#     650.0,
#     None,
#     None],
#    ['2017-05-26',
#     166.0778,
#     167.533778,
#     165.836435,
#     167.486089,
#     128.0,
#     None,
#     None],
#    ['2017-05-25',
#     165.345918,
#     166.545932,
#     163.417916,
#     166.545932,
#     645.0,
#     None,
#     None],
#    ['2017-05-24',
#     166.330844,
#     166.753233,
#     164.965379,
#     164.965379,
#     1004.0,
#     None,
#     None],
#    ['2017-05-23',
#     167.352754,
#     167.352754,
#     165.366356,
#     166.575129,
#     1977.0,
#     None,
#     None],
#    ['2017-05-22',
#     168.300696,
#     168.300696,
#     164.83691,
#     167.338155,
#     1572.0,
#     None,
#     None],
#    ['2017-05-19',
#     169.943537,
#     170.81946,
#     167.677818,
#     167.677818,
#     797.0,
#     None,
#     None],
#    ['2017-05-18',
#     168.245221,
#     170.899266,
#     167.931836,
#     169.34499,
#     2998.0,
#     None,
#     None],
#    ['2017-05-17',
#     172.078841,
#     172.078841,
#     168.540115,
#     168.540115,
#     2646.0,
#     None,
#     None],
#    ['2017-05-16',
#     172.104146,
#     173.237979,
#     172.070082,
#     172.575197,
#     265.0,
#     None,
#     None],
#    ['2017-05-15',
#     172.12945,
#     172.260839,
#     171.251581,
#     172.229695,
#     924.0,
#     None,
#     None],
#    ['2017-05-12',
#     172.546973,
#     172.589796,
#     171.167882,
#     171.494893,
#     1976.0,
#     0.988837,
#     17.0],
#    ['2017-05-11',
#     174.653278,
#     175.046892,
#     172.042332,
#     172.42921,
#     1692.0,
#     None,
#     None],
#    ['2017-05-10',
#     176.813828,
#     176.813828,
#     173.900694,
#     174.672525,
#     1094.0,
#     None,
#     None],
#    ['2017-05-09',
#     175.33657,
#     177.012079,
#     174.999736,
#     176.837887,
#     1802.0,
#     None,
#     None],
#    ['2017-05-08',
#     178.810772,
#     178.810772,
#     175.00166,
#     175.56273,
#     3101.0,
#     None,
#     None],
#    ['2017-05-05',
#     176.706041,
#     178.137104,
#     176.017937,
#     177.781023,
#     875.0,
#     None,
#     None],
#    ['2017-05-04',
#     176.665621,
#     180.7442,
#     176.1161,
#     176.1161,
#     8258.0,
#     None,
#     None],
#    ['2017-05-03',
#     176.117062,
#     176.117062,
#     173.125013,
#     175.249955,
#     1197.0,
#     None,
#     None],
#    ['2017-05-02',
#     177.367198,
#     177.567374,
#     175.881278,
#     176.432724,
#     2077.0,
#     None,
#     None],
#    ['2017-05-01',
#     177.010154,
#     177.010154,
#     177.010154,
#     177.010154,
#     0.0,
#     None,
#     None],
#    ['2017-04-28',
#     177.350837,
#     178.512434,
#     176.510677,
#     177.010154,
#     1261.0,
#     None,
#     None],
#    ['2017-04-27',
#     178.039904,
#     178.472014,
#     177.908057,
#     178.472014,
#     357.0,
#     None,
#     None],
#    ['2017-04-26',
#     178.471051,
#     179.003249,
#     177.817593,
#     178.17175,
#     1297.0,
#     None,
#     None],
#    ['2017-04-25',
#     177.823367,
#     178.958017,
#     177.752151,
#     178.953205,
#     1523.0,
#     None,
#     None],
#    ['2017-04-24',
#     176.404815,
#     178.119781,
#     176.157482,
#     177.505781,
#     2715.0,
#     None,
#     None],
#    ['2017-04-21',
#     171.910486,
#     173.91513,
#     171.802699,
#     173.91513,
#     947.0,
#     None,
#     None],
#    ['2017-04-20',
#     169.643111,
#     171.776715,
#     169.643111,
#     171.776715,
#     225.0,
#     None,
#     None],
#    ['2017-04-19',
#     171.010658,
#     171.010658,
#     171.010658,
#     171.010658,
#     0.0,
#     None,
#     None],
#    ['2017-04-18',
#     171.951868,
#     172.854584,
#     170.814332,
#     171.010658,
#     689.0,
#     None,
#     None],
#    ['2017-04-17',
#     171.068401,
#     171.068401,
#     171.068401,
#     171.068401,
#     0.0,
#     None,
#     None],
#    ['2017-04-14',
#     171.068401,
#     171.068401,
#     171.068401,
#     171.068401,
#     0.0,
#     None,
#     None],
#    ['2017-04-13',
#     170.828767,
#     171.677589,
#     170.422642,
#     171.068401,
#     620.0,
#     None,
#     None],
#    ['2017-04-12',
#     169.534362,
#     170.944253,
#     169.43235,
#     170.944253,
#     1542.0,
#     None,
#     None],
#    ['2017-04-11',
#     170.678636,
#     171.200247,
#     168.773117,
#     169.461221,
#     1003.0,
#     None,
#     None],
#    ['2017-04-10',
#     171.496661,
#     171.496661,
#     170.227278,
#     170.227278,
#     482.0,
#     None,
#     None],
#    ['2017-04-07',
#     169.582481,
#     171.785376,
#     169.179243,
#     171.560179,
#     1449.0,
#     None,
#     None],
#    ['2017-04-06',
#     167.695248,
#     169.993419,
#     167.341091,
#     169.993419,
#     1316.0,
#     None,
#     None],
#    ['2017-04-05',
#     171.01547,
#     171.01547,
#     169.252384,
#     169.523776,
#     298.0,
#     None,
#     None],
#    ['2017-04-04',
#     169.956848,
#     171.048191,
#     168.869355,
#     171.048191,
#     808.0,
#     None,
#     None],
#    ['2017-04-03',
#     171.496661,
#     172.644784,
#     168.934798,
#     169.149409,
#     2938.0,
#     None,
#     None],
#    ['2017-03-31',
#     171.181,
#     171.919147,
#     170.628592,
#     171.530345,
#     306.0,
#     None,
#     None],
#    ['2017-03-30',
#     171.170413,
#     171.267614,
#     170.341802,
#     170.760438,
#     379.0,
#     None,
#     None],
#    ['2017-03-29',
#     172.046182,
#     172.046182,
#     170.911532,
#     171.630432,
#     1066.0,
#     None,
#     None],
#    ['2017-03-28',
#     171.207946,
#     171.688175,
#     170.642065,
#     170.642065,
#     508.0,
#     None,
#     None],
#    ['2017-03-27',
#     170.919231,
#     171.007771,
#     169.318788,
#     170.780648,
#     1556.0,
#     None,
#     None],
#    ['2017-03-24',
#     173.132712,
#     173.132712,
#     171.785376,
#     171.871991,
#     430.0,
#     None,
#     None],
#    ['2017-03-23',
#     172.813201,
#     173.133675,
#     171.288786,
#     172.747759,
#     742.0,
#     None,
#     None],
#    ['2017-03-22',
#     172.266568,
#     172.651521,
#     171.804624,
#     172.266568,
#     2109.0,
#     None,
#     None],
#    ['2017-03-21',
#     173.97961,
#     175.634908,
#     172.708302,
#     173.534989,
#     1828.0,
#     None,
#     None],
#    ['2017-03-20',
#     176.452934,
#     176.641561,
#     174.20192,
#     174.610933,
#     2403.0,
#     None,
#     None],
#    ['2017-03-17',
#     176.212338,
#     176.940862,
#     175.432808,
#     176.057395,
#     1680.0,
#     None,
#     None],
#    ['2017-03-16',
#     174.480049,
#     177.766587,
#     174.095095,
#     176.308577,
#     14356.0,
#     None,
#     None],
#    ['2017-03-15',
#     169.186942,
#     173.209703,
#     169.186942,
#     173.209703,
#     4368.0,
#     None,
#     None],
#    ['2017-03-14',
#     173.381007,
#     173.381007,
#     168.561393,
#     168.878017,
#     2307.0,
#     None,
#     None],
#    ['2017-03-13',
#     173.132712,
#     173.339625,
#     172.249245,
#     172.939273,
#     3849.0,
#     None,
#     None],
#    ['2017-03-10',
#     171.785376,
#     172.960446,
#     170.774874,
#     172.335859,
#     2738.0,
#     None,
#     None],
#    ['2017-03-09',
#     167.983963,
#     173.024926,
#     167.45369,
#     171.648718,
#     6553.0,
#     None,
#     None],
#    ['2017-03-08',
#     158.793205,
#     168.079239,
#     158.793205,
#     168.032082,
#     19993.0,
#     None,
#     None],
#    ['2017-03-07',
#     154.055393,
#     154.522149,
#     153.276825,
#     153.98129,
#     1501.0,
#     None,
#     None],
#    ['2017-03-06',
#     154.847434,
#     155.441225,
#     154.270004,
#     154.270004,
#     926.0,
#     None,
#     None],
#    ['2017-03-03',
#     155.815592,
#     156.103344,
#     154.741572,
#     154.762745,
#     1247.0,
#     None,
#     None],
#    ['2017-03-02',
#     154.414362,
#     157.380427,
#     153.773415,
#     156.675962,
#     1228.0,
#     None,
#     None],
#    ['2017-03-01',
#     152.469386,
#     154.806052,
#     152.469386,
#     154.420136,
#     1733.0,
#     None,
#     None],
#    ['2017-02-28',
#     151.09414,
#     152.536753,
#     150.997902,
#     152.536753,
#     1131.0,
#     None,
#     None],
#    ['2017-02-27',
#     148.206991,
#     152.347163,
#     148.110753,
#     151.833251,
#     5358.0,
#     None,
#     None],
#    ['2017-02-24',
#     146.875053,
#     147.31005,
#     145.276535,
#     146.302435,
#     837.0,
#     None,
#     None],
#    ['2017-02-23',
#     147.155107,
#     147.660358,
#     146.684501,
#     147.146445,
#     354.0,
#     None,
#     None],
#    ['2017-02-22',
#     146.281263,
#     147.242683,
#     146.281263,
#     147.199376,
#     1358.0,
#     None,
#     None],
#    ['2017-02-21',
#     142.659815,
#     146.871203,
#     142.659815,
#     146.165777,
#     717.0,
#     None,
#     None],
#    ['2017-02-20',
#     142.913884,
#     143.411436,
#     142.672326,
#     142.672326,
#     839.0,
#     None,
#     None],
#    ['2017-02-17',
#     142.264276,
#     143.003386,
#     140.989118,
#     143.003386,
#     1367.0,
#     None,
#     None],
#    ['2017-02-16',
#     143.997528,
#     143.997528,
#     142.401897,
#     142.401897,
#     576.0,
#     None,
#     None],
#    ['2017-02-15',
#     145.41608,
#     145.41608,
#     143.57023,
#     143.999452,
#     935.0,
#     None,
#     None],
#    ['2017-02-14',
#     144.920453,
#     146.236031,
#     144.920453,
#     145.367961,
#     693.0,
#     None,
#     None],
#    ['2017-02-13',
#     143.972506,
#     146.282225,
#     143.972506,
#     145.39587,
#     676.0,
#     None,
#     None],
#    ['2017-02-10',
#     142.629981,
#     144.357459,
#     142.629981,
#     143.656844,
#     789.0,
#     None,
#     None],
#    ['2017-02-09',
#     138.89401,
#     142.66174,
#     138.89401,
#     142.468301,
#     1954.0,
#     None,
#     None],
#    ['2017-02-08',
#     139.689901,
#     139.689901,
#     137.620778,
#     138.714045,
#     1227.0,
#     None,
#     None],
#    ['2017-02-07',
#     138.811245,
#     140.05272,
#     138.089458,
#     138.467675,
#     4155.0,
#     None,
#     None],
#    ['2017-02-06',
#     141.855263,
#     141.855263,
#     138.038452,
#     138.038452,
#     2142.0,
#     None,
#     None],
#    ['2017-02-03',
#     141.570398,
#     141.9592,
#     141.254736,
#     141.717642,
#     410.0,
#     None,
#     None],
#    ['2017-02-02',
#     141.47031,
#     142.709859,
#     141.47031,
#     141.493407,
#     771.0,
#     None,
#     None],
#    ['2017-02-01',
#     141.3452,
#     142.54048,
#     140.604165,
#     141.778272,
#     1969.0,
#     None,
#     None],
#    ['2017-01-31',
#     144.646174,
#     146.283187,
#     140.204776,
#     140.915015,
#     4286.0,
#     None,
#     None],
#    ['2017-01-30',
#     147.244608,
#     147.491941,
#     144.549936,
#     144.793418,
#     2940.0,
#     None,
#     None],
#    ['2017-01-27',
#     149.497547,
#     150.016271,
#     147.937524,
#     147.937524,
#     1874.0,
#     None,
#     None],
#    ['2017-01-26',
#     148.737264,
#     149.670776,
#     148.737264,
#     148.976898,
#     609.0,
#     None,
#     None],
#    ['2017-01-25',
#     147.491941,
#     149.542779,
#     147.491941,
#     148.253186,
#     1948.0,
#     None,
#     None],
#    ['2017-01-24',
#     147.167617,
#     149.169374,
#     147.055019,
#     147.366831,
#     1821.0,
#     None,
#     None],
#    ['2017-01-23',
#     146.57094,
#     147.244608,
#     146.185987,
#     146.715297,
#     1372.0,
#     None,
#     None],
#    ['2017-01-20',
#     146.246617,
#     146.992464,
#     144.526838,
#     146.133056,
#     1006.0,
#     None,
#     None],
#    ['2017-01-19',
#     145.717306,
#     147.109874,
#     145.021503,
#     146.313984,
#     1465.0,
#     None,
#     None],
#    ['2017-01-18',
#     142.066987,
#     145.803921,
#     142.066987,
#     145.777936,
#     1129.0,
#     None,
#     None],
#    ['2017-01-17',
#     142.492361,
#     142.492361,
#     141.325952,
#     141.794633,
#     61.0,
#     None,
#     None],
#    ['2017-01-16',
#     141.90242,
#     142.955267,
#     141.806181,
#     142.689649,
#     1482.0,
#     None,
#     None],
#    ['2017-01-13',
#     140.792792,
#     142.336455,
#     140.02481,
#     142.265238,
#     1264.0,
#     None,
#     None],
#    ['2017-01-12',
#     140.12971,
#     140.716764,
#     139.545544,
#     140.716764,
#     566.0,
#     None,
#     None],
#    ['2017-01-11',
#     139.430058,
#     140.409764,
#     139.129794,
#     140.409764,
#     434.0,
#     None,
#     None],
#    ['2017-01-10',
#     138.775637,
#     139.850619,
#     138.775637,
#     139.559979,
#     364.0,
#     None,
#     None],
#    ['2017-01-09',
#     140.219212,
#     140.267331,
#     138.936355,
#     139.220258,
#     1923.0,
#     None,
#     None],
#    ['2017-01-06',
#     138.995061,
#     139.544581,
#     137.620778,
#     139.544581,
#     354.0,
#     None,
#     None],
#    ['2017-01-05',
#     140.245196,
#     140.940999,
#     138.787186,
#     138.787186,
#     1506.0,
#     None,
#     None],
#    ['2017-01-04',
#     143.491314,
#     144.028324,
#     140.255782,
#     140.255782,
#     3538.0,
#     None,
#     None],
#    ['2017-01-03',
#     146.232181,
#     146.367877,
#     143.395076,
#     143.7117,
#     1393.0,
#     None,
#     None],
#    ['2017-01-02',
#     144.068744,
#     146.120545,
#     144.068744,
#     145.320804,
#     5334.0,
#     None,
#     None]],
#   'collapse': None,
#   'order': None,
#   'database_id': 15302}}

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
#Create list of just the dates and prices
adidas_temp = r.json()
adidas = adidas_temp['dataset']['data']

# %%
#Turn the list of lists in to a dictionary
adidas_2017 ={}
for line in adidas:
    key, value = line[0], line[1:]
    adidas_2017[key] = value

# %%
#3. Calculate what the highest and lowest opening prices were for the stock in this period.
opening_prices = []
for value in adidas_2017.values():
    opening_prices.append(value[0])
print('The highest opening price was ' + str(max(opening_prices)))
print('The lowest opening price was ' + str(min(opening_prices)))
# Out:
# The highest opening price was 193.968141
# The lowest opening price was 138.775637

# %%
#4. What was the largest change in any one day (based on High and Low price)?
daily_change = []
for value in adidas_2017.values():
    d_change = value[1] - value[2]
    daily_change.append(d_change)
print('The largest change in one day was ' + str(max(daily_change)))
# Out:
# The largest change in one day was 11.081390999999996

# %%
#5. What was the largest change between any two days (based on Closing Price)?

closing_prices = []
for value in adidas_2017.values():                               
    closing_prices.append(value[3])

largest_change = 0
for i in range(len(closing_prices) - 2):
    two_day_change = abs(closing_prices[i+1] - closing_prices[i])
    if two_day_change > largest_change:
        largest_change = two_day_change
            
print('The largest closing price change between two days was ' + str(largest_change))
# Out:
# The largest closing price change between two days was 14.050792000000001

# %%
#6. What was the average daily trading volume during this year?

daily_trade_vol = []
for value in adidas_2017.values():
    daily_trade_vol.append(value[4])

avg = sum(daily_trade_vol)/len(daily_trade_vol)
print('The average daily trading volume was ' + str(avg))
print(daily_trade_vol)
# Out:
# The average daily trading volume was 1638.323076923077
# [1060.0, 1019.0, 1121.0, 0.0, 0.0, 2067.0, 2173.0, 1489.0, 752.0, 1661.0, 1826.0, 3261.0, 5067.0, 2348.0, 2903.0, 2083.0, 1281.0, 1351.0, 1917.0, 1975.0, 3104.0, 1521.0, 1363.0, 880.0, 2280.0, 2592.0, 814.0, 2712.0, 2106.0, 2654.0, 779.0, 636.0, 2694.0, 2052.0, 1926.0, 6443.0, 13020.0, 503.0, 1410.0, 4602.0, 849.0, 737.0, 2762.0, 0.0, 1656.0, 781.0, 663.0, 1593.0, 1011.0, 835.0, 539.0, 1841.0, 820.0, 211.0, 1411.0, 970.0, 165.0, 239.0, 492.0, 696.0, 1423.0, 1123.0, 1493.0, 0.0, 5681.0, 595.0, 1046.0, 4222.0, 1402.0, 945.0, 1605.0, 585.0, 1959.0, 274.0, 255.0, 200.0, 921.0, 460.0, 156.0, 1769.0, 532.0, 797.0, 861.0, 0.0, 528.0, 669.0, 946.0, 564.0, 1422.0, 1660.0, 2191.0, 6148.0, 0.0, 333.0, 562.0, 3420.0, 316.0, 2014.0, 470.0, 1556.0, 1745.0, 1675.0, 1425.0, 1210.0, 1360.0, 2618.0, 2454.0, 706.0, 1238.0, 1751.0, 10388.0, 4820.0, 124.0, 885.0, 667.0, 179.0, 284.0, 524.0, 878.0, 1612.0, 1670.0, 503.0, 3761.0, 893.0, 472.0, 659.0, 3333.0, 2892.0, 655.0, 682.0, 2058.0, 2741.0, 0.0, 617.0, 1105.0, 434.0, 517.0, 368.0, 270.0, 342.0, 448.0, 100.0, 2326.0, 1257.0, 564.0, 545.0, 552.0, 1526.0, 1689.0, 0.0, 1847.0, 291.0, 539.0, 1065.0, 650.0, 128.0, 645.0, 1004.0, 1977.0, 1572.0, 797.0, 2998.0, 2646.0, 265.0, 924.0, 1976.0, 1692.0, 1094.0, 1802.0, 3101.0, 875.0, 8258.0, 1197.0, 2077.0, 0.0, 1261.0, 357.0, 1297.0, 1523.0, 2715.0, 947.0, 225.0, 0.0, 689.0, 0.0, 0.0, 620.0, 1542.0, 1003.0, 482.0, 1449.0, 1316.0, 298.0, 808.0, 2938.0, 306.0, 379.0, 1066.0, 508.0, 1556.0, 430.0, 742.0, 2109.0, 1828.0, 2403.0, 1680.0, 14356.0, 4368.0, 2307.0, 3849.0, 2738.0, 6553.0, 19993.0, 1501.0, 926.0, 1247.0, 1228.0, 1733.0, 1131.0, 5358.0, 837.0, 354.0, 1358.0, 717.0, 839.0, 1367.0, 576.0, 935.0, 693.0, 676.0, 789.0, 1954.0, 1227.0, 4155.0, 2142.0, 410.0, 771.0, 1969.0, 4286.0, 2940.0, 1874.0, 609.0, 1948.0, 1821.0, 1372.0, 1006.0, 1465.0, 1129.0, 61.0, 1482.0, 1264.0, 566.0, 434.0, 364.0, 1923.0, 354.0, 1506.0, 3538.0, 1393.0, 5334.0]

# %%
#7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)
def calc_median(num_list):
    sorted_num_list = sorted(num_list)
    if len(num_list) % 2:
        median_place = int(len(num_list) / 2)
        return (num_list[median_place] - num_list[median_place - 1])
    else:
        median_place = int((len(num_list) - 1) / 2)
        return num_list[median_place]

calc_median(daily_trade_vol)
# Out:
# 682.0
